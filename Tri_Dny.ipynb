# %%
import pandas as pd
import json
import re
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
BOS, EOS = ' ', '\n'
PAD = "<PAD>"
with open('lyrics.json', 'r') as file:
    text = str(json.load(file))

couplets = re.findall(r'Verse.*?(?=Chorus|Verse|\Z)', text, re.DOTALL)
choruses = re.findall(r'Chorus.*?(?=Verse|Chorus|\Z)', text, re.DOTALL)

cleaned_couplets = [re.sub(r'\[.*?\]', '', couplet).strip() for couplet in couplets]
cleaned_choruses = [re.sub(r'\[.*?\]', '', chorus).strip() for chorus in choruses]

lines = ' '.join(cleaned_couplets + cleaned_choruses)

# %%
tokens = set(" ".join(lines))
tokens = sorted(tokens)
n_tokens = len(tokens)
print ('n_tokens = ',n_tokens)
# Out:
# n_tokens =  134

# %%
char_to_int = {symbol: index for index, symbol in enumerate(tokens, start=1)}
char_to_int[PAD] = 0


n_tokens = len(char_to_int)
n_tokens
# Out:
# 135

# %%
class SymbolDataset(Dataset):

    def init(self, data, token_to_ids):
        self.data = data
        self.token_to_ids = token_to_ids

    def len(self):
        return len(self.data)

    def getitem(self, index):
        symbols = [self.token_to_ids[symbol] for symbol in self.data[index]]
        symbols.append(self.token_to_ids['EOS'])
        return symbols

# %%
train_lines, dev_lines = train_test_split(lines, test_size=0.25, random_state=42)
train_dataset = SymbolDataset(train_lines, char_to_int)
train_loader = DataLoader(train_dataset, batch_size=64)

# %%
def collation(batch, pad=char_to_int[PAD], dtype=np.int64):
    max_len = max(map(len, batch))
    lines_ix = np.full([len(batch), max_len], pad, dtype=dtype)
    for i in range(len(batch)):
        lines_ix[i, :len(batch[i])] = batch[i]
    return torch.from_numpy(lines_ix)

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collation)
test_dataset = SymbolDataset(dev_lines, char_to_int)
test_loader = DataLoader(test_dataset, batch_size=64, collate_fn=collation)

# %%
class LSTM(nn.Module):
    def __init__(self, n_vocab, hidden_dim, embedding_dim, dropout=0.5):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.embedding_dim = embedding_dim
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, dropout=dropout, num_layers=2)
        self.embeddings = nn.Embedding(n_vocab, embedding_dim)
        self.fc = nn.Linear(hidden_dim, n_vocab)

    def forward(self, s):
        embedded = self.embeddings(s.t())
        lstm_out, _ = self.lstm(embedded)
        ht = lstm_out[-1]
        out = self.fc(ht)
        return out

# %%
PAD = "<PAD>"
char_to_int[PAD]=0
class Window(nn.Module):
    def __init__(self, n_tokens=90, emb_size=32, hid_size=128):
        super().__init__()
        PAD = "<PAD>"
        stride = 1
        kernel_size = 5
        num_leading_zeros = (kernel_size - 1) * stride
        self.embedding = nn.Embedding(n_tokens, emb_size,  padding_idx=char_to_int[PAD])
        self.padding = nn.ZeroPad2d((num_leading_zeros, 0, 0, 0))
        self.conv = nn.Conv1d(emb_size, hid_size, kernel_size=kernel_size, stride=stride)
        self.lr = nn.Linear(hid_size, n_tokens)

    def __call__(self, input_ix):
        emb = self.embedding(input_ix)
        emb = emb.permute(0, 2, 1)
        padded = self.padding(emb)
        conved = self.conv(padded)
        relu = F.relu(conved)
        relu = relu.permute(0, 2, 1)
        out = self.lr(relu)
        return out

# %%
model = LSTM(140,256,256)
model.cuda()
model2 = Window()
model2.cuda()
# Out:
# Window(
#   (embedding): Embedding(90, 32, padding_idx=0)
#   (padding): ZeroPad2d((4, 0, 0, 0))
#   (conv): Conv1d(32, 128, kernel_size=(5,), stride=(1,))
#   (lr): Linear(in_features=128, out_features=90, bias=True)
# )

# %%
train_history =[]
dev_history = []

n_epochs = 10
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
for epoch in range(n_epochs):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    avg_loss = 0.
    for i, (x_batch, y_batch) in enumerate(train_loader):
        y_pred = model(x_batch)

        loss = loss_fn(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()

        optimizer.step()
        avg_loss += loss.item() / len(train_loader)
    print('Epoch',epoch + 1, "Loss",avg_loss)

    total_batches = 0.0
    test_loss = 0.0
    test_perplexity = 0.0
    model.eval()
    for i, (x_batch, y_batch) in enumerate(test_loader):
        with torch.no_grad():
            y_pred = model(x_batch)
            loss = loss_fn(y_pred, y_batch)
            test_loss += loss.item()
            total_batches += 1

    average_loss = test_loss / total_batches
    perplexity = torch.exp(torch.tensor(average_loss))
    print(f'Epoch {epoch + 1}, Perplexity: {perplexity.item()}')
# Out:
# Epoch 1 Loss 0.9409210691979851
# Epoch 1, Perplexity: 3.2265830039978027
# Epoch 2 Loss 0.8923759344333851
# Epoch 2, Perplexity: 3.1833624839782715
# Epoch 3 Loss 0.8491629263697136
# Epoch 3, Perplexity: 3.1415321826934814
# Epoch 4 Loss 0.8114479335678462
# Epoch 4, Perplexity: 3.104315996170044
# Epoch 5 Loss 0.7787136187062843
# Epoch 5, Perplexity: 3.1114096641540527
# Epoch 6 Loss 0.7478762851833483
# Epoch 6, Perplexity: 3.0973474979400635
# Epoch 7 Loss 0.7218480091343985
# Epoch 7, Perplexity: 3.114409923553467
# Epoch 8 Loss 0.7025173436186316
# Epoch 8, Perplexity: 3.1059584617614746
# Epoch 9 Loss 0.6780534099421692
# Epoch 9, Perplexity: 3.11103892326355
# Epoch 10 Loss 0.6628822844202928
# Epoch 10, Perplexity: 3.0989725589752197

# %%
train_history =[]
dev_history = []
n_epochs = 10
optimizer = torch.optim.Adam(model2.parameters(), lr=1e-3)
for epoch in range(n_epochs):
    model2.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    avg_loss = 0.
    for i, (x_batch, y_batch) in enumerate(train_loader):
        out = model2(x_batch)
        out = out.view(out.shape[0] * out.shape[1], -1)
        y = y_batch.flatten()
        loss_i = F.cross_entropy(out, y, ignore_index=char_to_int[PAD])
        optimizer.zero_grad()
        loss_i.backward()
        optimizer.step()

        avg_loss += loss.item() / len(train_loader)
    print('Epoch',epoch + 1, "Loss",avg_loss)

    total_batches = 0.0
    test_loss = 0.0
    test_perplexity = 0.0
    model2.eval()
    for i, (x_batch, y_batch) in enumerate(test_loader):
        with torch.no_grad():
            out = model2(x_batch)
            out = out.view(out.shape[0] * out.shape[1], -1)
            y = y_batch.flatten()
            loss_i = F.cross_entropy(out, y, ignore_index=char_to_int[PAD])
            dev_history.append(((epoch + 1) * len(train_loader) + i, loss_i.item()))
            test_loss += loss_i.item()
            total_batches += 1

    average_loss = test_loss / total_batches
    perplexity = torch.exp(torch.tensor(average_loss))
    print(f'Epoch {epoch + 1}, Perplexity: {perplexity.item()}')
# Out:
# Epoch 1 Loss 2.45899752261417
# Epoch 1, Perplexity: 7.7531633377075195
# Epoch 2 Loss 1.9761667397709637
# Epoch 2, Perplexity: 5.886527061462402
# Epoch 3 Loss 1.7589298354751832
# Epoch 3, Perplexity: 5.001465320587158
# Epoch 4 Loss 1.613346935064068
# Epoch 4, Perplexity: 4.513491630554199
# Epoch 5 Loss 1.5030794097827034
# Epoch 5, Perplexity: 4.187100410461426
# Epoch 6 Loss 1.4171446672523695
# Epoch 6, Perplexity: 3.9566500186920166
# Epoch 7 Loss 1.3435874333077489
# Epoch 7, Perplexity: 3.7946159839630127
# Epoch 8 Loss 1.2842630781256614
# Epoch 8, Perplexity: 3.6342613697052
# Epoch 9 Loss 1.2339607620701478
# Epoch 9, Perplexity: 3.5452473163604736
# Epoch 10 Loss 1.1877307793063776
# Epoch 10, Perplexity: 3.4760284423828125

# %%
int_to_char = {i: symbol for symbol, i in char_to_int.items()}

# %%
def generate(model, prompt, max_len=10000, temperature=0.2):
    model.eval()
    token_ids = [char_to_int[symbol] for symbol in prompt]
    input_tensor = torch.LongTensor(token_ids).unsqueeze(0).cuda()
    generated_symbols = []

    criterion = torch.nn.CrossEntropyLoss()

    total_prob = 0.0
    num_tokens = 0

    while len(generated_symbols) < max_len:
        with torch.no_grad():
            out = model(input_tensor)[:, -1, :]
            if temperature == 0:
                max_v, ind = torch.max(out, axis=1)
                token = ind.cpu()[0].item()
            else:
                probs = F.softmax(out / temperature, dim=1)
                token = np.random.choice(list(range(len(char_to_int))), p=probs[0].cpu().numpy())
                ind = torch.LongTensor([token]).cuda()

            if token == char_to_int[EOS]:
                break

            loss = criterion(out, torch.LongTensor([token]).cuda())
            probs += loss.item()
            num_tokens += 1

            generated_symbols.append(int_to_char[token])
            input_tensor = torch.cat([input_tensor, ind.unsqueeze(0)], axis=1)

    perplexity = torch.exp(probs / num_tokens)
    generated_text = prompt + "".join(generated_symbols)

    return perplexity, generated_text

# %%
prompt = 'Все таки тогда ты была не'
perplexity, text = generate(model, prompt)
text
# Out:
# Все таки тогда ты была не подоконите
# Это не ссомные глаза
# И всё направився не закатые класты
# От меня нашей силые любви
# От всех не насилие, что мне нужно столос
# Я растолком вино пеходи (Прощайствой
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыха-а-а-а
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыхаешь об асфал)
# Всё это очень скучно?
# На небо сточно навсегда
# Не будем домой, как в этом со множем спроство
# В этом не ляжем спроствя
# Мы не устало на пороге
# Чужие для меня
# Эта остался всё закроется планеты
# Что меня рядом нету
# Не пятаю алкоголь красивая
# И открые слазки всегда
# Ты убиваешь меня свои глаза
# Не смей мешать от темперенось в это небо скучно
# Но ты снова до твоих глазах
# Твои глаза, словно петей, как всегда, как всегда, в этом нету
#
# Каждый новый квартире весной вины
# Не знаю, что такое себе в мире красота
# В моей квартире весна, медленно сходим с ума
# Ты ушила и твои слова — ведь наплетам
#
# Две всё же твои слова всё рассказать
# Все от скроешь меня не закатывала всё из-за тебя
# Это один по промокла красивая
#
# И снова зима, как я не настолечный раз, колько знала ты оставлю на прошло
# Я последнег до городом
# Как же меня осень скучно, но не наситереть
# [Припев: Глеб Викторов, только тебе подали
# Когда я умру, когда я умру, когда я умру
#
# Сколько уже ты так делала раз?
# Сколько себет молится силые только напротив меня
# Где ты?
# Я бы всегда написил меня
# От этого страдает моя голова
# Каждый раз сводим с ума красивая
#
# Как же меня спросят чёрный телефоно
# Где бы я не прощен — такое любви
# Пока мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не виделись заряти всех
# Когда мы не смей мешать на твоих глаз, когда я умру
# Не кури, не киряй, не кури, не киряй
# Бедная юность, что я любил тебя пять
# Мне снова пьяный хород (Е-е)
# Она небо страшный раз, который яз себяем каждую ночь
# Твой ночью всё напротив меня
# Из твоего дома напротив меня
# Ведь мы не люжим с тобой вспомнить стекла
# Не кури, не киряй. Бэйби попадают в рай
# Не кури, не киряй, не кури, не киряй, не кури, не киряй
#
# Не кури, не киряй, не кури, не кури, не киряй
#
# Не кури, не киряй, не кури, не киряй. Бэйби попадают второтка, свои для меня
# Ты снова скажет на всё заебало
# Как же меня оставлю тебя лишь напасим не звони, не знах, ности себя убежать
# В моей конца оставлетки на раз?
# И сколько уже ты с тобой, что тебя, для меня
# Так от себя скажу, всегда, всё прощешь помочь
# Мы был снова подали — ведь ты полезала без твоих глазах
# И скажу, но ты нет тебе
# За окном тут и не носишь меня
# Что не снова спрятая как (Не помню, как всегда, а ты уже не молет для называми
# Когда я умру, когда мы делала раз?
# И как мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжемся спять
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не подомнил подумаю, как всегда, но тебе не смей мешать
# Ты снова так — ты убью тебя
#
#
#
#
# Твои глаза красим меня с тобой не в одной венный новый день ты не знаешь
# Все мои друзья, все мои друзья, обезщаю твои глаза
# В колько ты слёб, чтоб его всё рассопать
# Я покажу тебя, и я так делала раз?
# И как у тебя делала раз?
# В этом теперь для меня
# Твои глаза, отпускай, от-отпускай
# От-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай…
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
#
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-убиваешь тобой по парфюм
# Когда я умру, когда я умру
# Не кури, не киряй. Бэйби попадают в рай
# Не кури, не киряй. Бэйби папапапают раз
#
# Как же меня зацупала
# Не замечаю, нам не замечаю лишних глаз
# И не смей мешать о твоих руки
# Не выводи меня
# От этого нету
# Не виноваты планеты
# Что меня рядом нету
#
# Я не замечаю любви (Нет и не знаю, что всё заебало
# Когда я умру, когда я умру, когда я умру, когда я умру
# Не звони, но меня твоего дома
# Я бы ты заеменный раз)
# Ты пока я любил тебя лишь наполовину
# Сожги меня, которые не подумал
# Ты так делала раз?
# Я не высодно внутри — тебе всё из-за тебя
# Могут любить меня
# От этого слёзы
# Сожги меня, пока мы смей мешать
# Запиши и стирай, запиши и стирай
#
# Зашли за край, стирай, цикл, мы зашли за край
# Зашли за край, стирай, цикл, мы зашли за край
# Зашли за край, стирай, цикл, мы зашли за край
# Зашли за край, стирай, цикл, мы зашли и стирай
# Не кури, не киряй, не кури, не киряй, не кури, не киряй
# Не кури, не киряй, не кури, не киряй
# Мне не спостолные любовь и табленно
# Ведь мы был сон (И не снова всё худшее в осколках
# Ведь не смей мешать от спаскоме темном и дверь
# Меня заебало луна
# Ты снова будешь подам
# И все мои друзья, все мои друзья, все мои друзья, все мои друзья, все мои друзья — все мои глаза
# Опять твои глаза, а ты не знаю
# Но это очень скучно
# Наркотики и слова бы не насилие
# Сожги меня, не знаю, как всё заебало
# Не уходи, нас там не твои нежный этого сейчас
# Это слова из тебя
# Она могу скроешь квартире
# Когда я умру, как мне не знаю, что всего лучшие отда
# В моей рукь, осень домой, пока я смей мешать, не знаю, как я на наши слазки
#
# Веди меня не двами
# Каждый раз с соботел о твои любви
#
# В конца осень ждыт настолелные подым был под дождя
# Если ты меня всегда, что мы не половина
# Ты просто, чтобы не смей мешать
# В моей поръём, что ты девочка рок-н-ролл
# Моя малышка рок-н-ролл
#
# Я не любил тебя как делала раз?
# И как всегда не постели
#
#
# Обнимая на последнем на твоей постели
# Пока я спятаю всё расстенет
# Моя демоны, демоны, демоны меня не одолели
# Твои губы, снова темное наполовина
# Кожда мне не ждут, как всегда
#
# Как же, всё худшее во мне прищеня
# Где от тебя не помню, когда я сплю всегда не замечаю наплво
# В давно, что было всё расскажи, как про тебя как шлах
# Ты подолжала раз?
# И снова бесконечно из никогда, но не был (Не перебивай)
# Всё те же грабли (Пропев: MONA,
# Глеб Викторов
# ]
# Ненавижу тебя
# Sk8er boi
# Что мне снова бузыка один
# Я не так хочешь вспомнил со мной?
# Был за твоих глазах
# Не замечаю, малыш, молчи мало руке красивая
#
# Все мои друзья, всем играем
# Мы снова не останусь сигарет наполовину
# Сожги меня, для меня остался
# И мы не насилие отоб (Это перепевказь
#
#
#
#
#
#
# (Отпускай…
# Сколько уже ты так делала рассказать
# И снова твои слова как всегда, но не хочу на пороге
# Чтобы ты просто не почень и кокстол, меня своими чувствуя с менять
# От этого страдает моя голова
# Каждый новый день ты убиваешь меня
# Не уходи, нас там не ждут
# Не уходи, нас там не ждут
# Не уходи, нас там не ждут
# Не уходи, нас там не ждут
# Не уходи, нас там не убежать
# Не уходи, нас там не закатые нельз
# И не нужен могит теперь
#
# Ты высотели всех лишь слова нам красив еставь последнего день ты снова симена, останусь на мои голоса
#
#
# Меня не знаю, чтоб его всё
# Не виноваты планеты
# Что меня рядом нету
#
# Эта осень слышу твои глаза
# И вся сердце всё напроголела
# Все это нам нежно такое стебя
# Ты высоте
# Ты как храсота
# За окном так для меня, а ты племний раз
# Все разбуду всё всё раз
#
#
# В нашей квартире весна, медленно сходим с ума
# Пока я сплю в пустой недоравно
#
# Все мои друзья, с тобой свезь посколно из твоего домома напротив меня
# Из твоего дома подевочь из конца
#
#
#
#
#
# Отпускай)-о--о-л, меня как последний раз?
#
#
#
#
# Отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай)
# (Отпускай…
#
# От-отпускай)
# Отпускай, от-отпускай)
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай)
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай…
# От-отпускай, от-отпускай)
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай, отпускай…
# (Отпускай) Чужи в последнемная путь
#
# Всё из-за тебя, и я такой весь из твоего дома
# Я помню меня не замечаю, не замечаю, не замечаю, возни меня
# Пока я умру
# Не коква за меня заглушный раз, я как такой всегда не зановаться
# Голоса, чтобы не смей мешать
# Выдыхай
# Выдыхай
# Самый квартире весна, медленно сходим с ума
# Что такое люби меня напостол
# Дождь бы от тебя
#
# Отпускай…
# (От-отпускай, от-отпускай)
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай
#
# Отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай)
# Отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай)
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай)
# От-отпускай, от-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай
# От-отпускай, от-отпускай…
# Чужие голоса, мы спросят в моей кармам
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# И мы не ляжем спать
# В моей комнате телефон, всё просто всём
#
# Каждый раз)
# И не смог дле домой, пока я умру
# Не кирей, не киряй, не кури, не киряй
# Без пока ты влюблена взовина
# Когда же ты так делала розы
# В комнате поделой, а-а!
# Я закрою ночь и твой голос за твои луна
# Каждую ночь на всё просто не прошлого
# Где мой домой веный вдох)
#
# И снова закрутаться на всегда
#
# Когда я умру, когда я снова мне так подергамо
# Я отправлюсь в лиц
# Ты убиваешь меня
# Ненавижу тебя
# Sk8er boi
# (overylme, methylone
# And speaking an thore sould nelp all of this was a dream, chann and
# of this was a dream (Taking an inhale again)
# If only all of this was a dream, methylmethcanthinone
# And I wans though it again
# If only all a dream, methylmy tould scupcopst
# I don't it a dream (Slowly taking an inhale again)
#
# I want you sk8er boi
# I hate you sk8er boi
# I hake love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, but spindle and again
#
# I want you sids strppiding it hant you want you want this was all off of this was a dream (Taking an inhale again)
#
# Sowly taking an inhale again)
# If only all of this was a dream (Taking an inhale again)
# Thought it again)
# If only all of this was a dream, methylmothcantione
# And there

# %%
perplexity
# Out:
# 3.358577251434318

# %%
perplexity2, text2 = generate(model2, prompt, 0.1)
text2
# Out:
# Все таки тогда ты была не вина
# Когда же меня не подал (Я убежать
# И снова бесконечный раз
# А я хочу тебя колно запрошло
# Как же меня зацепило
# Не виноваты планеты
# Что меня рядом нету
#
# Я люблю и ненавижу тебя
# Sk8er boi
# (udbye, my love
# Goodbye, my love
# Goodbye
# Gou’re bvens
# I hate you sk8er boi
# I hate you paking
# I stupst this love
# Goodbye, that you sk8er boi
# I hate you sk8er boi
# I hate you sk8er boi
# Coke kryptonite
# I want you sk8er boi
# And this like kryptonite, that in this Eplone
# And thap there you there, and I hate this
# Goken there this
# Gotery puts
# And thrould sould spin all of this was a dream (Slowly taking an inhale again)
# If only all of my wounds an whore
# It's jut sk8er boi
# I want you sk8er boi
# I hate you love (Fake love
# Goodbye, my love),
# I’m (Sk8er boi
# (kake love), lave in. That I dont this was a dream
# If only all of chould I pant this was a dream (Taking an inhale again)
#
# You’t a dream (Taking an. I don't this was a dream (Taking an inhale again)
# If only all of this was a dream, my measite
# If only all of this was a dream (Taking an inhale again)
# If only all of this was a dream (Slowly taking an inhale again)
# If only all of this was a dream (Taking an inhale again)
#
# You’re want I yarnver tor spin to scrokenn fould pantite
# It's jut scust I hate your ny thore off only all of this was a dream (Take it..
# If only all of this was a dream (Taking an inhale again)
# If only all of this was a dream, methylmethcethinone
# And I hate you sk8er bois I hate you sk8er boi
# I hate you this sp8er boi
# I hate you war you, my love
# Goodbye, my love, like, love)
# Goodbye, my love, my love)
# Goodbye, me love
# Gake love)
# Goodbye, my love)
# Goodbye, my love)
# Goodbye, my love
# Goodbye, me haver to fike soverele
# Wan there though it aght you, you you sk8er boi
# I hate you sk8er boi
# I hate you. I’m buk this
# And thant you'll whis tone; I’m want the still toule
# I was you'd this was a dream, mhylmethcathinone
# Ifon tone spindle would lile again
# You’re again)
# If only all of this was a dream (Taking an inhale again)
# If only all of my wouss stut sk8er boi
# I hate it. You’re would I’m again)
# If only all of this was a dream (Slowly taking an inhale again)
# If only again
# If only all of this was a dream (Taking an inhale again
#
# You’re was you'll songh you wang an this
# And I want toueres Pup, and pups I warn taking an inhalis a dream, methylmethcathing through though it again
# If only all of this was a dream (Slowlyy taking an inhale again)
# You’re wall all of this was a dream, methylmething the spindle would peut was a dream, me this stryptonised
# If only all of this was a dream, methylmethcathinone
# And there of this want you want it was a dream, methylmem, my cot
# If only all of this was a dream (Taking an inhale wann again)
# If only all of this was a dream (Taking leathing an to want and again)
# If onll all of this was a dream, mantith to sinre to shike love
# Goodbye, my love
# Gove sore tas kaking an inhale again)
#
# You’re wans it a dream (Yeaking an inhale again)
#
# Sonly taking an inhale again)
# If only all of this was a dream, methylmething this
# And I hate you a dream, methylmethcathing thore I hath you spike kryptonite, I hate, bhys this Lunt fo want tou stepps in there; I’m a dream (Yeant
# If only all of this love
# Бevkyer to fill of this pake lowly taking an inhale again)
#
# You’re want to sen fild spin all you sk8er boi
# I want you all you, and I’m haverethylof this want you sk8er boi
# I was you want tou sk8er boi
# I sp8er boi
# I hake thing tasting an inhale again
#
# You’re we want the was all a dream, methylmethcathincone
# And the spindle would I do tald stup wart a dream (Yean)
# If only all of this was a dream (Taking an inhale again)
# Thought realize
# I want you, and I hate it. Tet it. You’re want in all of this was a dream, methylmythcenone
# And I’m all of this was a dream (Slowly taking an inhale again)
#
# You’re whoret we spin thoce we want to sk8er boi
# I haking it. I love you sk8er boi
# I hate you sk8er boi
# I hate it. You’ry I don spindle would spin all of my would spindle though it as a dream, methylmething
# I’m I hate this lover eake from my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love
# Goodbye, my love, lips like kryptonite
# What you sk8er boi
# I hate you sk8er boi
# I hate you want to it. I wat, ye a meay, bu this
# Gou’re bupsf thiss we like kryptonite, it’s pryptonise
# I hate you sk8er boi
# I'ke kryptonite
#
# Кого ты спросят было руке, а не смей мешать
# И мы не ляжемся спастение
# Ты крестолел, чтобы снова пьяный
# Я знаю, что мы не больше не найду, не пусто всюгда
#
#
#
# Из твоего дома напротив меня
# Из твоего дома заглушно похуй, обнимаю стиктре в глаза
# Я не зводи, от твоих глазах
# Твои глаза, все хотел с тобой
# Я был сон (Е-е), эй
#
# Ты пелена двазадцать напротився
# Я избегаю тебя
# Это такое всей в осталось оставлит тебя
# Но не спесте, чтобы не выходи
# Не замечаю, не звони, не звони, не звони, новый дествет
# Твои мало луна
# И сколько уже ты так делала раз?
# Ищу тебя я умру, когда я умру — я сделался всю просто не убежать
# И мы не ляжем спать
# И мы не ляжем спять и не нихуя
# Ты снова так снова всё так хочешь всех
# Что меня рядом нету
#
# И как всё рассказали с тобой
# Ненавижу тебя, не кури, не киряй
# Не кури, не киряй. Бэйби попадают в рай
# Не кури, не киряй, не киряй
#
#
#
# Мне будет планеты
# Что меня рядом нету
# И последний расскажи, как всем мире красома
# Я не знаю, что меня назрогам
# Я зеркала всё растобоя напол
# Каждую стекла
#
# От любви меня просил бы всего прошлое
# Ты так делала раз?
# И как у тебе скажут больше не знаю, что мне слова захотела
# Только тебе слова для меня
# От этого доме полезали — такое с тобой
# Ты убью тебя
# Sk8er boi
# (Как обезами, мы не ляжем спать
# Всю ночь тобой дышать
# Всю ночь тобой дышать
# Выдыхай разбивай всердцах
# Ведь один как
# Могут любить малолетки в любви
# Это не закроется навсегда
#
# Обещал, что я сердце до ждут
# Не уходи, нас там не ждут
# Не уходи, нас там не ждут
# Не души меня напился
# Но я снова поснемного губы
# В конца ты уже не снает плать
# В моей голос на пороге
# Чтобы не тысячный раз, колько скажи, в кого было всё из-за тебя
# Могут любить меня не нажну
# Что так ещё не списовенно, где не настолет
# И как последний раз, я падаю разбиваю всёх
#
#
#
# Спасив меня свои глаза, не выдыха-а-ай
# Выдыха-а-ай
# Выдыха-а-ай
# Выдыхай
#
#
#
# Из как мы смелеш теперь из сон
# И скажать чассом чувство мире квартире
# В моей расстворит меня сказать
# Голоса всё часскажешь от всех настолько провода
# Я покажу тебя
# Sk8er boi
# (u-oodbye, my love
# Goodbye, my love
# Goodbye, baking an inhale again
# If only a dream (Yeah)
# If only all of this was a dream, methylmytthing this frokeng
# In't this was a dream (Taking an inhale again)
# If only all of this was a dream (Taking an inhale again)
#
# You’re wead
# If only all of this was a dream, methylmy toceensting to hing an inhale again)
# If only all of this was a dream, methylmething thround I don’t was a dream, but I dox there; I want you stupss and and and it.
# Ye again)
# If only all of fo this was a dream, methylmong thing it’s all all of this was a dream (Taking an inhale again
#
# I don't this was a dream, methylmomencethcathinone
# I do suped spindle again
# If only all of dy tou, and I hate stupid
# If only all of this was a dream, methylmethcathinone
# And there want to skert no fis speall thoce you seraking I hate you sk8er boi
# I hate you sk8er boi (Yeah)
# If only all of this was a dream (Taking an inhale again)
# If only all of this was a dream (Yeaking an all of my wough it again)
# Though it again)
# If only all of this was a dream, methylcantcathinone
# And shard of this whore’s ne thome would like and this
# That you sk8er boi
# I hate it. I hall this was a dream, methylmythcathinone
# And thould stup slorlled
# If only all of this was a dream (Taking an inhale again)
# If only all of this was a dream, methylmathinhing thorething thore, I peycthing
# I thould want to sons
# I want you sk8er bike
# I sk8er boi
# (u-oodbye, my love
# Gondbye, my love
# Goodbye, bake love (Fake love, fake love
# Goodbye, my love
# Goodbye, my, and I dove a drom (Saken throre faking an inhale again)
# If only all of this was a dream, methylltethone
# And I don's taking an this was a dream (Sloveving methylsthone
# And it’s wans it was a dream (Yeawize
# It's just we want to sk8er boi fuxp af and
# If'me, my thet suuld spin want you’s was a dream, methylmethinght bunnte
# And I hate it. You’re paking this want it again
# If only all of this was a dream, methylmything
# I scuup, and I hate in this
# Whye a dream, methylmethcone
# And I hate put spindle again)
# If only all a dream, but I’m again)
# If only all of it. I gut stusped this was a dream (Yean)
# Yomh
# I want you was you, and I hate it. You’re my poiss
# I hate it all a love it. I don’t this
# Tou’re a duxs afding thoum, scully
# If only all of this was a dream (Taking an inhale again)
#
# Yo akenly all of my and I hate it’s want you sk8er boi
# I hate you sk8er boi
# I hate you, and take love (Yeak (Yeak
# I don't this was a dream (Taking an inhale again)
#
# It's jups you'll so frop, ye and I hate it. You’s you sk8er boi
# I hate you, than you sk8er boi
# I hate you sk8er boi
# I hate it. You’re there thould sould shought sonr of non tuls whor sore my my sou teess
# I’m a dream (Baking an inhale again
#
# You’re who sealli, and again)
# If onling an this was a dream (Taking an inhale again)
# If only all of this was a dream, methylmethcathinone
# And I dunds spindle again
#
# I want and and it’s want you want to this
# Where you stuck it. I do thiss like kryptonite
# I want you sk8er boi
# Что я останусь в тебе всегда, не знаю, не хочешь напервы
# Не будет стучит на всё картия
#
# В окном призномок, чтобы не последнем и новой пустолетки
# В отпускай, от-отпускай
# От-отпускай, от-отпускай)
# От-отпускай, от-отпускай
# От-отпускай)
#
# Отпускай…
#
# Мы продолжаешь от себя
# Пока я ссобнил снова без памяти слова
# Каждый наркотико всегда разболь
# Как же меня зацеки
# Ты поделала за нам не касать
# В моей голове, чтобы не знаю, полножь наедине
# Каждый новый день ты молчишь — я скажу
# Я покажу тебя, и всё заебало
# Кожды всё разбила — точно не насить
# И всё двжать от тебя
# Это слёзы на ветер
# Заедемоны, демоны, демоны, демоны не ждут
# Не уходи,

# %%
perplexity2
# Out:
# 5.45659725149364
